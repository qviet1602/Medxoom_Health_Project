# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix,accuracy_score, classification_report
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, GridSearchCV, cross_validate, train_test_split
from math import sqrt

# %%
data=pd.read_csv("./merged_final_data.csv",dtype=str)
data['hospital system or, if independent, ipps/cah'].nunique()
print(data.shape)
# Out:
# (3329, 87)

# %%
data=data.drop(columns=['hospital name','city','hospital system or, if independent, ipps/cah',
                       'state','street address'])

# %%
#print number of Nan per coulmns
nan_col=data.columns[data.isnull().any()]
for n in nan_col:
    print(n,data[n].isnull().sum())
    
#drop columns have more than 70% Nan
for n in nan_col:
    if data[n].isnull().sum()/len(data)>0.7:
        data.drop(n,1,inplace=True)
data.shape
# Out:
# hospital compare 5-star rating (october 2018, na=not available) 476
# number of outpatient services 37
# total private allowed amount for outpatient services ($ millions) 37
# simulated medicare allowed amount for outpatient services ($ millions) 37
# relative price for outpatient services 37
# standardized price per outpatient service 37
# number of inpatient stays 1664
# total private allowed amount for inpatient services ($ millions) 1664
# simulated medicare allowed amount for inpatient services ($ millions) 1664
# relative price for inpatient services 1664
# standardized price per inpatient stay 1664
# total private allowed amount for inpatient and outpatient services ($ millions) 1701
# simulated medicare allowed amount for inpatient and outpatient services ($ millions) 1701
# relative price for professional inpatient and outpatient services 1743
# relative price for inpatient facility services 1709
# relative price for outpatient facility services 251
# relative price for inpatient and outpatient services 1701
# total private allowed amount for facility inpatient and outpatient services ($ millions) 1743
# simulated medicare allowed amount for facility inpatient and outpatient services ($ millions) 1743
# total private allowed amount for professional inpatient and outpatient services ($ millions) 1743
# simulated medicare allowed amount for professional inpatient and outpatient services ($ millions) 1743
# hospital compare 5-star rating (october 2018, n/a = not available) 3200
# Total Discharges 593
# Total Discharges.1 596
# Total Discharges.2 601
# Average Covered Charges 593
# Average Covered Charges.1 596
# Average Covered Charges.2 601
# Average Total Payments 593
# Average Total Payments.1 596
# Average Total Payments.2 601
# Average Medicare Payments 593
# Average Medicare Payments.1 596
# Average Medicare Payments.2 601
# Average Estimated Total Submitted Charges 1592
# Average Estimated Total Submitted Charges.1 1037
# Average Estimated Total Submitted Charges.2 1040
# Average Medicare Allowed Amount 1592
# Average Medicare Allowed Amount.1 1037
# Average Medicare Allowed Amount.2 1040
# Average Medicare Payment Amount 1592
# Average Medicare Payment Amount.1 1037
# Average Medicare Payment Amount.2 1040
# Outlier Comprehensive APC Services 1711
# Outlier Comprehensive APC Services.1 1139
# Outlier Comprehensive APC Services.2 1055
# Average Medicare Outlier Amount 1711
# Average Medicare Outlier Amount.1 1139
# Average Medicare Outlier Amount.2 1055
# Revenue from sale of medical and surgical supplies to other than patients [other_income_supplies_nonpat] 2646
# Revenue from sale of drugs to other than patients [other_income_drugs_nonpat] 2470
# Tuition (fees, sale of textbooks, uniforms, etc.) [other_income_tuition] 2679
# Revenue from gifts, flowers, coffee shops, and canteen [other_income_gifts] 2636
# Rental of vending machines [other_income_vending] 2387
# Governmental appropriations [other_income_govt_approp] 2826
# Revenues from State and local indigent care programs (2552-96 only) [revs_uncomp_stloc_indig_only96] 2653
# Revenues related to SCHIP (2552-96 only) [revs_uncomp_schip_only96] 3022
# Restricted grants for Uncompensated care, Medicaid, and SCHIP (2552-96 only) [revs_uncomp_rstrgrants_only96] 3049
# Non-restricted grants for Uncompensated care, Medicaid, and SCHIP (2552-96 only) [revs_uncomp_nonrstrgrants_only96] 3146
# Charges for patients covered under state or local indigent care program [stloc_indigent_charges] 2464
# State or local indigent care program cost [stloc_indigent_costs] 2472
# Stand-alone SCHIP charges [schip_charges] 2822
# Stand-alone SCHIP cost [schip_costs] 2829
# Inpatient days, Medicare skilled nursing facility swing beds [mdcr_snf_swingbed_inpat_days] 3171
# Inpatient days, skilled nursing facility swing beds [all_snf_swingbed_inpat_days] 3168
# Inpatient days, nursing facility swing beds [all_nf_swingbed_inpat_days] 3212
# Inpatient days, other specialty care units [all_oth_spec_care_inpat_days] 2826
# Inpatient days, coronary care unit [all_coronary_care_inpat_days] 2853
# Inpatient days, burn intensive care unit [all_burn_icu_inpat_days] 3172
# Inpatient days, surgical intensive care unit [all_surgical_ic_inpat_days] 3163
# Revenue from rental of living quarters [other_income_livingrental] 2927
# Revenue from laundry and linen service [other_income_laundry] 2928
# Parking lot receipts [other_income_parking] 2910
# Rebates and refunds of expenses [other_income_rebates] 2606
# Nursing and allied health managed care payment [mdcr_ipps_nurs_mgdcare_pymts] 2403
# Net organ acquisition cost [mdcr_ipps_net_organ_cost] 3161
# Cost of teaching physicians [mdcr_ipps_teach_phys_cost] 3328
# Routine service other pass through costs [mdcr_ipps_routine_passthru_cost] 2812
# medicare provider number.1 2052
# (3329, 52)

# %%
# rearrange column (put reponse colkumn to the end)
data = data[[c for c in data if c not in ['relative price for inpatient and outpatient services']] 
       + ['relative price for inpatient and outpatient services']]
# remove % at the end of these 2 columns
data['relative price for inpatient facility services'] = data['relative price for inpatient facility services'].str.rstrip('%').astype('float')
data['relative price for outpatient facility services'] = data['relative price for outpatient facility services'].str.rstrip('%').astype('float')

# convert object data type column to dummy variables
labelencoder = LabelEncoder()
cat_features=[x for x in data.columns if data[x].dtype=="object"]
for col in cat_features:
    if col in data.columns:
        i = data.columns.get_loc(col)
        data.iloc[:,i] = data.apply(lambda i:labelencoder.fit_transform(i.astype(str)), axis=0, result_type='expand')

# convert all to numeric

data = data.apply(pd.to_numeric, errors='ignore')
data
# Out:
#       medicare provider number  zip code  \
# 0                            0       844
# 1                            1       834
# 2                            2       826
# 3                            3       820
# 4                            4       835
# ...                        ...       ...
# 3324                      3318      2198
# 3325                      3320      2378
# 3326                      3322      2214
# 3327                      3326      2259
# 3328                      3327      2381
#
#       is hospital a critical access hospital (y/n)?  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 3324                                              0
# 3325                                              0
# 3326                                              0
# 3327                                              0
# 3328                                              0
#
#       hospital compare 5-star rating (october 2018, na=not available)  \
# 0                                                     1
# 1                                                     0
# 2                                                     2
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 3324                                                  5
# 3325                                                  5
# 3326                                                  5
# 3327                                                  5
# 3328                                                  5
#
#       number of outpatient services  \
# 0                               898
# 1                               783
# 2                                84
# 3                               581
# 4                               303
# ...                             ...
# 3324                           1188
# 3325                            960
# 3326                            443
# 3327                            663
# 3328                            808
#
#       total private allowed amount for outpatient services ($ millions)  \
# 0                                                    11
# 1                                                     4
# 2                                                     9
# 3                                                     6
# 4                                                     3
# ...                                                 ...
# 3324                                                 10
# 3325                                                 10
# 3326                                                  0
# 3327                                                 40
# 3328                                                  0
#
#       simulated medicare allowed amount for outpatient services ($ millions)  \
# 0                                                     9
# 1                                                     2
# 2                                                     4
# 3                                                     4
# 4                                                     2
# ...                                                 ...
# 3324                                                  0
# 3325                                                  0
# 3326                                                  0
# 3327                                                 10
# 3328                                                  0
#
#       relative price for outpatient services  \
# 0                                         26
# 1                                        120
# 2                                         98
# 3                                         72
# 4                                         17
# ...                                      ...
# 3324                                     359
# 3325                                     415
# 3326                                     296
# 3327                                     443
# 3328                                     118
#
#       standardized price per outpatient service  number of inpatient stays  \
# 0                                          3120                        504
# 1                                           675                        504
# 2                                           280                        330
# 3                                           127                        504
# 4                                          3126                        504
# ...                                         ...                        ...
# 3324                                       2214                        504
# 3325                                       2573                        504
# 3326                                       1761                        504
# 3327                                       2737                        504
# 3328                                        188                        504
#
#       ...  Average Medicare Payment Amount.1  \
# 0     ...                               2291
# 1     ...                               2291
# 2     ...                               2291
# 3     ...                               2291
# 4     ...                               2291
# ...   ...                                ...
# 3324  ...                                134
# 3325  ...                               2291
# 3326  ...                                 49
# 3327  ...                                128
# 3328  ...                                283
#
#       Average Medicare Payment Amount.2  Outlier Comprehensive APC Services  \
# 0                                  2288                                 263
# 1                                  2288                                 263
# 2                                  2288                                 263
# 3                                  2288                                 263
# 4                                  2288                                 263
# ...                                 ...                                 ...
# 3324                                196                                 263
# 3325                               2288                                 263
# 3326                                199                                 263
# 3327                                137                                 263
# 3328                                144                                 263
#
#       Outlier Comprehensive APC Services.1  \
# 0                                      552
# 1                                      552
# 2                                      552
# 3                                      552
# 4                                      552
# ...                                    ...
# 3324                                   237
# 3325                                   552
# 3326                                   552
# 3327                                   552
# 3328                                   112
#
#       Outlier Comprehensive APC Services.2  Average Medicare Outlier Amount  \
# 0                                      697                              448
# 1                                      697                              448
# 2                                      697                              448
# 3                                      697                              448
# 4                                      697                              448
# ...                                    ...                              ...
# 3324                                   231                              448
# 3325                                   697                              448
# 3326                                     0                              448
# 3327                                     0                              448
# 3328                                     0                              448
#
#       Average Medicare Outlier Amount.1  Average Medicare Outlier Amount.2  \
# 0                                   992                                975
# 1                                   992                                975
# 2                                   992                                975
# 3                                   992                                975
# 4                                   992                                975
# ...                                 ...                                ...
# 3324                                382                                348
# 3325                                992                                975
# 3326                                992                                  0
# 3327                                992                                  0
# 3328                                822                                  0
#
#       medicare provider number.1  \
# 0                           1277
# 1                           1277
# 2                           1277
# 3                           1277
# 4                           1277
# ...                          ...
# 3324                        1277
# 3325                        1277
# 3326                        1277
# 3327                        1277
# 3328                        1277
#
#       relative price for inpatient and outpatient services
# 0                                                   340
# 1                                                   340
# 2                                                   129
# 3                                                   340
# 4                                                   340
# ...                                                 ...
# 3324                                                340
# 3325                                                340
# 3326                                                340
# 3327                                                340
# 3328                                                340
#
# [3329 rows x 52 columns]

# %%
# filter to only labeled data
idx = data['relative price for inpatient and outpatient services'].isnull()
dt = data[~idx].reset_index(drop=True)
# fill NaN with imputation
dt.fillna(method="ffill", inplace=True)
dt.fillna(method="bfill", inplace=True)
print(dt.shape)
dt
# Out:
# (3329, 52)
#       medicare provider number  zip code  \
# 0                            0       844
# 1                            1       834
# 2                            2       826
# 3                            3       820
# 4                            4       835
# ...                        ...       ...
# 3324                      3318      2198
# 3325                      3320      2378
# 3326                      3322      2214
# 3327                      3326      2259
# 3328                      3327      2381
#
#       is hospital a critical access hospital (y/n)?  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 3324                                              0
# 3325                                              0
# 3326                                              0
# 3327                                              0
# 3328                                              0
#
#       hospital compare 5-star rating (october 2018, na=not available)  \
# 0                                                     1
# 1                                                     0
# 2                                                     2
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 3324                                                  5
# 3325                                                  5
# 3326                                                  5
# 3327                                                  5
# 3328                                                  5
#
#       number of outpatient services  \
# 0                               898
# 1                               783
# 2                                84
# 3                               581
# 4                               303
# ...                             ...
# 3324                           1188
# 3325                            960
# 3326                            443
# 3327                            663
# 3328                            808
#
#       total private allowed amount for outpatient services ($ millions)  \
# 0                                                    11
# 1                                                     4
# 2                                                     9
# 3                                                     6
# 4                                                     3
# ...                                                 ...
# 3324                                                 10
# 3325                                                 10
# 3326                                                  0
# 3327                                                 40
# 3328                                                  0
#
#       simulated medicare allowed amount for outpatient services ($ millions)  \
# 0                                                     9
# 1                                                     2
# 2                                                     4
# 3                                                     4
# 4                                                     2
# ...                                                 ...
# 3324                                                  0
# 3325                                                  0
# 3326                                                  0
# 3327                                                 10
# 3328                                                  0
#
#       relative price for outpatient services  \
# 0                                         26
# 1                                        120
# 2                                         98
# 3                                         72
# 4                                         17
# ...                                      ...
# 3324                                     359
# 3325                                     415
# 3326                                     296
# 3327                                     443
# 3328                                     118
#
#       standardized price per outpatient service  number of inpatient stays  \
# 0                                          3120                        504
# 1                                           675                        504
# 2                                           280                        330
# 3                                           127                        504
# 4                                          3126                        504
# ...                                         ...                        ...
# 3324                                       2214                        504
# 3325                                       2573                        504
# 3326                                       1761                        504
# 3327                                       2737                        504
# 3328                                        188                        504
#
#       ...  Average Medicare Payment Amount.1  \
# 0     ...                               2291
# 1     ...                               2291
# 2     ...                               2291
# 3     ...                               2291
# 4     ...                               2291
# ...   ...                                ...
# 3324  ...                                134
# 3325  ...                               2291
# 3326  ...                                 49
# 3327  ...                                128
# 3328  ...                                283
#
#       Average Medicare Payment Amount.2  Outlier Comprehensive APC Services  \
# 0                                  2288                                 263
# 1                                  2288                                 263
# 2                                  2288                                 263
# 3                                  2288                                 263
# 4                                  2288                                 263
# ...                                 ...                                 ...
# 3324                                196                                 263
# 3325                               2288                                 263
# 3326                                199                                 263
# 3327                                137                                 263
# 3328                                144                                 263
#
#       Outlier Comprehensive APC Services.1  \
# 0                                      552
# 1                                      552
# 2                                      552
# 3                                      552
# 4                                      552
# ...                                    ...
# 3324                                   237
# 3325                                   552
# 3326                                   552
# 3327                                   552
# 3328                                   112
#
#       Outlier Comprehensive APC Services.2  Average Medicare Outlier Amount  \
# 0                                      697                              448
# 1                                      697                              448
# 2                                      697                              448
# 3                                      697                              448
# 4                                      697                              448
# ...                                    ...                              ...
# 3324                                   231                              448
# 3325                                   697                              448
# 3326                                     0                              448
# 3327                                     0                              448
# 3328                                     0                              448
#
#       Average Medicare Outlier Amount.1  Average Medicare Outlier Amount.2  \
# 0                                   992                                975
# 1                                   992                                975
# 2                                   992                                975
# 3                                   992                                975
# 4                                   992                                975
# ...                                 ...                                ...
# 3324                                382                                348
# 3325                                992                                975
# 3326                                992                                  0
# 3327                                992                                  0
# 3328                                822                                  0
#
#       medicare provider number.1  \
# 0                           1277
# 1                           1277
# 2                           1277
# 3                           1277
# 4                           1277
# ...                          ...
# 3324                        1277
# 3325                        1277
# 3326                        1277
# 3327                        1277
# 3328                        1277
#
#       relative price for inpatient and outpatient services
# 0                                                   340
# 1                                                   340
# 2                                                   129
# 3                                                   340
# 4                                                   340
# ...                                                 ...
# 3324                                                340
# 3325                                                340
# 3326                                                340
# 3327                                                340
# 3328                                                340
#
# [3329 rows x 52 columns]

# %%
# split dataset to x and y
random_state = 100
x_data = dt.loc[:, dt.columns != "relative price for inpatient and outpatient services"]
y_data = dt.loc[:, "relative price for inpatient and outpatient services"]

# %%
#split dataset
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.25, shuffle=True, random_state=random_state)

regr = RandomForestRegressor(max_depth=None, random_state= random_state, n_estimators=100)
regr.fit(x_train, y_train)
y_pred = regr.predict(x_train)
rmse_random_forest_train = sqrt(mean_squared_error(y_train, y_pred))

print("RF MSE",rmse_random_forest_train) 

count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for ranrom forest: ',accuracy,"%")
# Out:
# RF MSE 6.454232799772088
# accuracy for ranrom forest:  57.57211538461539 %

# %%
#elastic net
en = ElasticNet(random_state=12345678)
en.fit(x_train,y_train)
y_pred = en.predict(x_train)
print('MSE for Elastic Net: '+ str(mean_squared_error(y_train, y_pred)))


count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for elastic net: ',accuracy,"%")
# Out:
# MSE for Elastic Net: 1194.5449561913947
# accuracy for elastic net:  1.6025641025641024 %

# %%
#Lasso
lasso_clf = LassoCV(cv=5, random_state=12345678).fit(x_train, y_train)
y_pred = lasso_clf.predict(x_train)
#print("Lasso accuracy",accuracy_score(y_test,y_pred))
print('MSE for Lasso: '+ str(mean_squared_error(y_train, y_pred)))
count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for Lasso: ',accuracy,"%")
# Out:
# MSE for Lasso: 1377.2885703384406
# accuracy for Lasso:  1.4022435897435899 %

# %%
#ridge
ridge_clf = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(x_train, y_train)
y_pred = ridge_clf.predict(x_train)
#print("Ridge accuracy",accuracy_score(y_test,y_pred))
print('MSE for Ridge: '+ str(mean_squared_error(y_train, y_pred)))
count=0
for i,j in zip(y_pred,y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for ridge: ',accuracy,"%")
# Out:
# MSE for Ridge: 1193.441244368235
# accuracy for ridge:  1.4823717948717947 %

# %%
#ridge
ridge_clf = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(x_train, y_train)
y_pred = ridge_clf.predict(x_train)
#print("Ridge accuracy",accuracy_score(y_test,y_pred))
print('MSE for Ridge: '+ str(mean_squared_error(y_train, y_pred)))
count=0
for i,j in zip(y_pred,y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for ridge: ',accuracy,"%")
# Out:
# MSE for Ridge: 1193.441244368235
# accuracy for ridge:  1.4823717948717947 %

# %%
#==============================================

# %%
#below code were trying to improve perfomance, but FAILED

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=12345678).fit(x_train,y_train)
y_predict_train=rf_clf.predict(x_train)
y_predict_test=rf_clf.predict(x_test)
#print("train set accuracy ",accuracy_score(y_train,y_predict_train)*100)
print("random forest accuracy", accuracy_score(y_test,y_predict_test )*100,"%")
print('MSE for rf: '+ str(mean_squared_error(y_train, y_pred)))
#get most important features
np.argsort(rf_clf.feature_importances_)
# Out:
# random forest accuracy 51.7406962785114 %
# MSE for rf: 1193.441244368235
# array([ 2, 44, 47, 46, 49, 48, 45,  3, 35, 40, 43, 38, 42, 41, 36, 39, 37,
#        26, 34, 27, 25, 28, 30, 24, 23, 33, 29, 32, 31,  6,  1,  5,  4,  0,
#         8, 18, 17,  7, 50, 11, 13, 19,  9, 10, 12, 20, 21, 22, 16, 15, 14])

# %%
#get top 30 features
dt.columns[[28, 30, 24, 23, 33, 29, 32, 31,  6,  1,  5,  4,  0,
        8, 18, 17,  7, 50, 11, 13, 19,  9, 10, 12, 20, 21, 22, 16, 15, 14]]
# Out:
# Index(['Average Covered Charges.2', 'Average Total Payments.1',
#        'Total Discharges.1', 'Total Discharges', 'Average Medicare Payments.1',
#        'Average Total Payments', 'Average Medicare Payments',
#        'Average Total Payments.2',
#        'simulated medicare allowed amount for outpatient services ($ millions)',
#        'zip code',
#        'total private allowed amount for outpatient services ($ millions)',
#        'number of outpatient services', 'medicare provider number',
#        'standardized price per outpatient service',
#        'relative price for outpatient facility services',
#        'relative price for inpatient facility services',
#        'relative price for outpatient services', 'medicare provider number.1',
#        'simulated medicare allowed amount for inpatient services ($ millions)',
#        'standardized price per inpatient stay',
#        'total private allowed amount for facility inpatient and outpatient services ($ millions)',
#        'number of inpatient stays',
#        'total private allowed amount for inpatient services ($ millions)',
#        'relative price for inpatient services',
#        'simulated medicare allowed amount for facility inpatient and outpatient services ($ millions)',
#        'total private allowed amount for professional inpatient and outpatient services ($ millions)',
#        'simulated medicare allowed amount for professional inpatient and outpatient services ($ millions)',
#        'relative price for professional inpatient and outpatient services',
#        'simulated medicare allowed amount for inpatient and outpatient services ($ millions)',
#        'total private allowed amount for inpatient and outpatient services ($ millions)'],
#       dtype='object')

# %%
dt2=dt[['Average Covered Charges.2', 'Average Total Payments.1',
       'Total Discharges.1', 'Total Discharges', 'Average Medicare Payments.1',
       'Average Total Payments', 'Average Medicare Payments',
       'Average Total Payments.2',
       'simulated medicare allowed amount for outpatient services ($ millions)',
       'zip code',
       'total private allowed amount for outpatient services ($ millions)',
       'number of outpatient services', 'medicare provider number',
       'standardized price per outpatient service',
       'relative price for outpatient facility services',
       'relative price for inpatient facility services',
       'relative price for outpatient services', 'medicare provider number.1',
       'simulated medicare allowed amount for inpatient services ($ millions)',
       'standardized price per inpatient stay',
       'total private allowed amount for facility inpatient and outpatient services ($ millions)',
       'number of inpatient stays',
       'total private allowed amount for inpatient services ($ millions)',
       'relative price for inpatient services',
       'simulated medicare allowed amount for facility inpatient and outpatient services ($ millions)',
       'total private allowed amount for professional inpatient and outpatient services ($ millions)',
       'simulated medicare allowed amount for professional inpatient and outpatient services ($ millions)',
       'relative price for professional inpatient and outpatient services',
       'simulated medicare allowed amount for inpatient and outpatient services ($ millions)',
       'total private allowed amount for inpatient and outpatient services ($ millions)','relative price for inpatient and outpatient services']]
dt2
# Out:
#       Average Covered Charges.2  Average Total Payments.1  Total Discharges.1  \
# 0                          1760                        13                2215
# 1                           440                      1850                1849
# 2                          1502                      2731                2013
# 3                          1835                       317                1328
# 4                          1816                      1817                 153
# ...                         ...                       ...                 ...
# 3324                       2728                      2733                2446
# 3325                       2728                      2733                2446
# 3326                        539                      2733                2446
# 3327                       2728                      2733                2446
# 3328                        695                      1567                 261
#
#       Total Discharges  Average Medicare Payments.1  Average Total Payments  \
# 0                 2245                         2417                    2703
# 1                 2028                         1370                    1915
# 2                 2122                         2349                    2645
# 3                 1441                         2632                      98
# 4                  224                         1411                    1531
# ...                ...                          ...                     ...
# 3324              2456                         2733                    2736
# 3325              2456                         2733                    2736
# 3326              2456                         2733                    2736
# 3327              2456                         2733                    2736
# 3328              2456                         1117                    2736
#
#       Average Medicare Payments  Average Total Payments.2  \
# 0                          2325                        33
# 1                          1430                      1872
# 2                          2248                      2306
# 3                          2428                       272
# 4                          1051                      1716
# ...                         ...                       ...
# 3324                       2736                      2728
# 3325                       2736                      2728
# 3326                       2736                      1575
# 3327                       2736                      2728
# 3328                       2736                      2143
#
#       simulated medicare allowed amount for outpatient services ($ millions)  \
# 0                                                     9
# 1                                                     2
# 2                                                     4
# 3                                                     4
# 4                                                     2
# ...                                                 ...
# 3324                                                  0
# 3325                                                  0
# 3326                                                  0
# 3327                                                 10
# 3328                                                  0
#
#       zip code  ...  number of inpatient stays  \
# 0          844  ...                        504
# 1          834  ...                        504
# 2          826  ...                        330
# 3          820  ...                        504
# 4          835  ...                        504
# ...        ...  ...                        ...
# 3324      2198  ...                        504
# 3325      2378  ...                        504
# 3326      2214  ...                        504
# 3327      2259  ...                        504
# 3328      2381  ...                        504
#
#       total private allowed amount for inpatient services ($ millions)  \
# 0                                                   686
# 1                                                   686
# 2                                                    48
# 3                                                   686
# 4                                                   686
# ...                                                 ...
# 3324                                                686
# 3325                                                686
# 3326                                                686
# 3327                                                686
# 3328                                                686
#
#       relative price for inpatient services  \
# 0                                       349
# 1                                       349
# 2                                       149
# 3                                       349
# 4                                       349
# ...                                     ...
# 3324                                    349
# 3325                                    349
# 3326                                    349
# 3327                                    349
# 3328                                    349
#
#       simulated medicare allowed amount for facility inpatient and outpatient services ($ millions)  \
# 0                                                   604
# 1                                                   604
# 2                                                     9
# 3                                                   604
# 4                                                   604
# ...                                                 ...
# 3324                                                604
# 3325                                                604
# 3326                                                604
# 3327                                                604
# 3328                                                604
#
#       total private allowed amount for professional inpatient and outpatient services ($ millions)  \
# 0                                                   409
# 1                                                   409
# 2                                                     8
# 3                                                   409
# 4                                                   409
# ...                                                 ...
# 3324                                                409
# 3325                                                409
# 3326                                                409
# 3327                                                409
# 3328                                                409
#
#       simulated medicare allowed amount for professional inpatient and outpatient services ($ millions)  \
# 0                                                   349
# 1                                                   349
# 2                                                     6
# 3                                                   349
# 4                                                   349
# ...                                                 ...
# 3324                                                349
# 3325                                                349
# 3326                                                349
# 3327                                                349
# 3328                                                349
#
#       relative price for professional inpatient and outpatient services  \
# 0                                                   242
# 1                                                   242
# 2                                                    37
# 3                                                   242
# 4                                                   242
# ...                                                 ...
# 3324                                                242
# 3325                                                242
# 3326                                                242
# 3327                                                242
# 3328                                                242
#
#       simulated medicare allowed amount for inpatient and outpatient services ($ millions)  \
# 0                                                   659
# 1                                                   659
# 2                                                    15
# 3                                                   659
# 4                                                   659
# ...                                                 ...
# 3324                                                659
# 3325                                                659
# 3326                                                659
# 3327                                                659
# 3328                                                659
#
#       total private allowed amount for inpatient and outpatient services ($ millions)  \
# 0                                                   905
# 1                                                   905
# 2                                                    44
# 3                                                   905
# 4                                                   905
# ...                                                 ...
# 3324                                                905
# 3325                                                905
# 3326                                                905
# 3327                                                905
# 3328                                                905
#
#       relative price for inpatient and outpatient services
# 0                                                   340
# 1                                                   340
# 2                                                   129
# 3                                                   340
# 4                                                   340
# ...                                                 ...
# 3324                                                340
# 3325                                                340
# 3326                                                340
# 3327                                                340
# 3328                                                340
#
# [3329 rows x 31 columns]

# %%
#re-train models
random_state = 100
x_data = dt2.loc[:, dt2.columns != "relative price for inpatient and outpatient services"]
y_data = dt2.loc[:, "relative price for inpatient and outpatient services"]
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.25, shuffle=True, random_state=random_state)

#Random forest
regr = RandomForestRegressor(max_depth=None, random_state= random_state, n_estimators=100)
regr.fit(x_train, y_train)
y_pred = regr.predict(x_train)
rmse_random_forest_train = sqrt(mean_squared_error(y_train, y_pred))

print("RF MSE",rmse_random_forest_train) 

count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for elastic net: ',accuracy,"%")
# Out:
# RF MSE 6.454232799772088
# accuracy for elastic net:  57.57211538461539 %

# %%
#elastic net
en = ElasticNet(random_state=12345678)
en.fit(x_train,y_train)
y_pred = en.predict(x_train)
print('MSE for Elastic Net: '+ str(mean_squared_error(y_train, y_pred)))


count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for elastic net: ',accuracy,"%")
# Out:
# MSE for Elastic Net: 1208.3390870001156
# accuracy for elastic net:  1.5625 %

# %%
#Lasso
lasso_clf = LassoCV(cv=5, random_state=12345678).fit(x_train, y_train)
y_pred = lasso_clf.predict(x_train)
#print("Lasso accuracy",accuracy_score(y_test,y_pred))
print('MSE for Lasso: '+ str(mean_squared_error(y_train, y_pred)))
count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for Lasso: ',accuracy,"%")
# Out:
# MSE for Lasso: 1398.0693631886957
# accuracy for Lasso:  1.1217948717948718 %

# %%
#ridge
ridge_clf = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(x_train, y_train)
y_pred = ridge_clf.predict(x_train)
#print("Ridge accuracy",accuracy_score(y_test,y_pred))
print('MSE for Ridge: '+ str(mean_squared_error(y_train, y_pred)))
count=0
for i,j in zip(y_pred,y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for ridge: ',accuracy,"%")
# Out:
# MSE for Ridge: 1208.4497943783608
# accuracy for ridge:  1.6025641025641024 %

# %%
#DT
cart_clf = DecisionTreeClassifier(max_depth=3, random_state=12345678).fit(x_train, y_train)
y_pred = cart_clf.predict(x_train)
print('MSE for Decision Tree: '+ str(mean_squared_error(y_train, y_pred)))
count=0
for i,j in zip(np.round(y_pred),y_train.to_numpy()):
    if i==j:
        count+=1
accuracy=count/len(y_train)*100
print('accuracy for Decision Tree: ',accuracy,"%")
# Out:
# MSE for Decision Tree: 1755.673076923077
# accuracy for Decision Tree:  52.76442307692307 %
